# %%
import pandas as pd
from astropy.coordinates import SkyCoord
import astropy.units as u
import glob
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from astropy.wcs import WCS

import photometry_functions as pf

# %%
dir = 'C:/Users/Tim/Downloads/535 Data/'

# %%
field_table = pd.read_csv(dir+'standards/field_table.csv')

RA = field_table['RA (J2000)']
DEC = field_table['Dec (J2000)']
Gmag = field_table['V']
Rmag = field_table['V']-field_table['V-R']
Imag = Rmag-field_table['R-I']

c = SkyCoord(RA,DEC, unit=(u.hourangle, u.deg))

field_table
# Out:
#       Star RA (J2000) Dec (J2000)       V    B-V    U-B    V-R    R-I  \
# 0  110 360   18:42:40   +00:09:10  14.618  1.197  0.539  0.715  0.717
# 1  110 361   18:42:45   +00:08:04  12.425  0.632  0.035  0.361  0.348
# 2  110 362   18:42:48   +00:06:26  15.693  1.333  3.919  0.918  0.885
# 3   110 L1   18:42:50   +00:07:10  16.252  1.752  2.953  1.066  0.992
# 4  110 266   18:42:49   +00:05:06  12.018  0.889  0.411  0.538  0.577
# 5  110 364   18:42:52   +00:07:54  13.615  1.133  1.095  0.697  0.585
# 6  110 365   18:42:57   +00:07:20  13.470  2.261  1.895  1.360  1.270
#
#            X          Y
# 0  1417.8908  1579.6706
# 1  1567.4297  1428.6083
# 2  1674.8174  1208.3935
# 3  1739.9907  1308.9297
# 4  1687.8623  1027.8024
# 5  1829.3971  1402.5939
# 6  1984.4428  1328.4724

# %%
filter='SR'

files = glob.glob(dir+'standards/*median*{}*.fits'.format(filter))

image = fits.open(files[0])
data = image[0].data
data = np.float64(data)
header = image[0].header
wcs = WCS(header)

xwcs, ywcs = wcs.all_world2pix(c.ra.deg, c.dec.deg,1)

x,y = field_table['X'],field_table['Y'] #wcs positions were inaccurate so use those to find real positions by-eye
plt.figure(figsize=(15,12))
plt.imshow(data,vmin=np.median(data),vmax=np.median(data)+100,origin='lower')
plt.scatter(x,y,edgecolor='red',facecolor='None',s=200)
plt.show()
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60221.120513 from DATE-OBS'. [astropy.wcs.wcs]

# %%
source_positions = np.column_stack((x, y))

if filter=='SR':
    M = Rmag
if filter=='SG':
    M = Gmag
if filter=='SI':
    M = Imag
    
median_FWHM = 4.7

# %% [markdown]
# # Aperture Photometry

# %%
# Display the table
phot_table = pf.ap_phot(data,header,source_positions,M,median_FWHM)

phot_table
# Out:
# <QTable length=7>
#   id   xcenter   ycenter  ...     zeropoint          counts_sec
#          pix       pix    ...
# int32  float64   float64  ...      float64            float64
# ----- --------- --------- ... ------------------ ------------------
#     1 1417.8908 1579.6706 ... 21.266418835973504  881.7948019364388
#     2 1567.4297 1428.6083 ...  21.39589655681541  5404.538596796069
#     3 1674.8174 1208.3935 ...  21.65810952144534  566.5572593556724
#     4 1739.9907 1308.9297 ... 21.233354799947342  262.3867619107132
#     5 1687.8623 1027.8024 ...  21.31519898410052  8591.709683109702
#     6 1829.3971 1402.5939 ...  21.32355069134252  2302.609417369733
#     7 1984.4428 1328.4724 ...  21.04734238709559 3757.8284911637497

# %%
#compute zeropoint and transformation coefficient
A = np.array(M-phot_table['Instr_Mag'])
B = np.array(field_table['V-R'])

X = np.vstack((B, np.ones(len(B)))).T

t, C = np.linalg.lstsq(X, A, rcond=None)[0]

print("transformation coefficient t:", t)
print("Zeropoint:", C)
# Out:
# transformation coefficient t: -0.24180010328160412
# Zeropoint: 21.515321622968237

# %% [markdown]
# # Do All Filters:

# %%
filters = ['SG','SR','SI']

for filter in filters:


    files = glob.glob(dir+'standards/*median*{}*.fits'.format(filter))

    image = fits.open(files[0])
    data = image[0].data
    data = np.float64(data)
    header = image[0].header
    wcs = WCS(header)

    xwcs, ywcs = wcs.all_world2pix(c.ra.deg, c.dec.deg,1)

    x,y = field_table['X'],field_table['Y'] #wcs positions were inaccurate so use those to find real positions by-eye
    
    source_positions = np.column_stack((x, y))

    if filter=='SR':
        M = Rmag
    if filter=='SG':
        M = Gmag
    if filter=='SI':
        M = Imag
    
    median_FWHM = 4.7
    
    phot_table = pf.ap_phot(data,header,source_positions,M,median_FWHM)
    
    #compute zeropoint and transformation coefficient
    A = np.array(M-phot_table['Instr_Mag'])
    B = np.array(field_table['V-R'])

    X = np.vstack((B, np.ones(len(B)))).T

    t, C = np.linalg.lstsq(X, A, rcond=None)[0]
    print('Filters:',filter)
    print("transformation coefficient t:", t)
    print("Zeropoint:", C)
    print(' ')
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60221.121434 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60221.120513 from DATE-OBS'. [astropy.wcs.wcs]
# Filters: SG
# transformation coefficient t: -0.672820589993529
# Zeropoint: 22.230457380267506
#
# Filters: SR
# transformation coefficient t: -0.24180010328160412
# Zeropoint: 21.515321622968237
#
# Filters: SI
# transformation coefficient t: -0.09577398515350131
# Zeropoint: 20.21298934479373
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60221.120995 from DATE-OBS'. [astropy.wcs.wcs]
