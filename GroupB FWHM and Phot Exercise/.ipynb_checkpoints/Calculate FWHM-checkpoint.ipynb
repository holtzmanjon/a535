# %%
from astropy.io import fits
import glob
from pandas import DataFrame
import matplotlib.pyplot as plt
import numpy as np
import astropy.units as u
from astropy.wcs import WCS
import pandas as pd
import astropy.units as u
from photutils.detection import DAOStarFinder

import photometry_functions as pf

# %%
dir = 'C:/Users/Tim/Downloads/535 Data/'

# %%
filter = 'SG'
file = glob.glob(dir+'standards/*median*{}*.fits'.format(filter))

image = fits.open(file[0])
data = image[0].data
header = image[0].header
wcs = WCS(header)

# get pixel scale in arcsec
px_scale = wcs.proj_plane_pixel_scales()[0].to(u.arcsec)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60221.121434 from DATE-OBS'. [astropy.wcs.wcs]

# %%
# Compute MAD of the background
bkg_mad = DataFrame(np.hstack(data)).mad(skipna = True)[0]

bkg_mad = DataFrame(np.hstack(data)).mad(skipna = True)[0]


# Find the sources
daofind = DAOStarFinder(threshold = 50*bkg_mad, fwhm = 4)
sources = daofind(data)

# Plot the sources with red circles
plt.imshow(data, vmin = np.median(data), vmax = np.median(data) + 100)
plt.scatter(sources['xcentroid'], sources['ycentroid'], facecolor = 'none', edgecolor = 'red')

sources
# Out:
# <QTable length=31>
#   id      xcentroid      ...        flux                mag
# int32      float64       ...      float64             float64
# ----- ------------------ ... ------------------ --------------------
#     1 2796.6443152319566 ...  8.094374325675872  -2.2704582113497747
#     2 3312.0130405412274 ...  3.030601499203104  -1.2038220843411134
#     3 2860.6084390862156 ... 1.6436908658699592   -0.539550354374195
#     4 2165.7062121324525 ... 1.1593247304040164  -0.1605127505419749
#     5   1794.74690662595 ... 26.046392738376273  -3.5393689618627504
#     6  3925.173048172604 ...  5.054683292801739  -1.7592348738543986
#     7  44.11855640192056 ...  15.94054808098116  -3.0062581239635433
#     8 1233.4552353987413 ... 1.3387464184899975  -0.3167458049646512
#     9  3114.382092544773 ... 1.6446510069746951  -0.5401843881997662
#    10 3651.7256065982547 ...  1.208980692763861 -0.20604841324980117
#   ...                ... ...                ...                  ...
# ...

# %%
fwhm = pf.FullWidth(data, sources, header, filter)

Seeing = fwhm.seeing()
# Out:
# Median FWHM: 4.7
# FWHM: 4.7008724727221 pixels
# Seeing: 2.0933888104503047 arcsec
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60221.121434 from DATE-OBS'. [astropy.wcs.wcs]
